# %%
import pandas as pd
import numpy as np

df = pd.read_csv('web_clients_correct.csv')
df.head()
# Out:
#                                               name device_type  \
# 0                    Allen  Miss. Elisabeth Walton      mobile
# 1                   Allison  Master. Hudson Trevor      tablet
# 2                     Allison  Miss. Helen Loraine      laptop
# 3             Allison  Mr. Hudson Joshua Creighton     desktop
# 4  Allison  Mrs. Hudson J C (Bessie Waldo Daniels)      laptop
#
#              browser     sex   age  bill                           region
# 0             Chrome  female  29.0   885                     St Louis: MO
# 1              Opera    male  48.0   850  Montreal: PQ / Chesterville: ON
# 2            Firefox  female  48.0  1034  Montreal: PQ / Chesterville: ON
# 3  Internet Explorer    male  30.0   214  Montreal: PQ / Chesterville: ON
# 4            Firefox  female  25.0   993  Montreal: PQ / Chesterville: ON

# %%
df['age_type'] = df['age'].apply(lambda x: np.where(x <= 25, 'Младше или равен 25', 'Старше 25'))
df.head()
# Out:
#                                               name device_type  \
# 0                    Allen  Miss. Elisabeth Walton      mobile
# 1                   Allison  Master. Hudson Trevor      tablet
# 2                     Allison  Miss. Helen Loraine      laptop
# 3             Allison  Mr. Hudson Joshua Creighton     desktop
# 4  Allison  Mrs. Hudson J C (Bessie Waldo Daniels)      laptop
#
#              browser     sex   age  bill                           region  \
# 0             Chrome  female  29.0   885                     St Louis: MO
# 1              Opera    male  48.0   850  Montreal: PQ / Chesterville: ON
# 2            Firefox  female  48.0  1034  Montreal: PQ / Chesterville: ON
# 3  Internet Explorer    male  30.0   214  Montreal: PQ / Chesterville: ON
# 4            Firefox  female  25.0   993  Montreal: PQ / Chesterville: ON
#
#               age_type
# 0            Старше 25
# 1            Старше 25
# 2            Старше 25
# 3            Старше 25
# ...

# %%
df[(df['sex'] == 'male') & (df['age'] > 30)].head()
# Out:
#                               name device_type            browser   sex   age  \
# 1   Allison  Master. Hudson Trevor      tablet              Opera  male  48.0
# 5              Anderson  Mr. Harry      mobile            Firefox  male  48.0
# 7           Andrews  Mr. Thomas Jr      tablet  Internet Explorer  male  39.0
# 9          Artagaveytia  Mr. Ramon      mobile            Firefox  male  71.0
# 10          Astor  Col. John Jacob     desktop             Chrome  male  47.0
#
#     bill                           region   age_type
# 1    850  Montreal: PQ / Chesterville: ON  Старше 25
# 5    371                     New York: NY  Старше 25
# 7    867                      Belfast: NI  Старше 25
# 9    926              Montevideo: Uruguay  Старше 25
# 10   100                     New York: NY  Старше 25
